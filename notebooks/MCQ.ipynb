# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import warnings
warnings.filterwarnings('ignore')

DATA_DIR  = 'dataset/'
SALES = DATA_DIR + 'sales.csv'
ORDERS = DATA_DIR + 'orders.csv'

# %% [markdown]
# Question 1: Trong số các khách hàng có nhiều hơn một đơn hàng, trung vị số ngày giữa hai lần mua liên tiếp (inter-order gap) xấp xỉ là bao nhiêu? (Tính từ orders.csv)

# %%
df_orders = pd.read_csv(ORDERS)
df_orders.head(10)
# Out:
#    order_id  order_date  customer_id   zip order_status payment_method  \
# 0         1  2012-07-04        58578  1109    delivered    credit_card
# 1         2  2012-07-04        58621  1330     returned            cod
# 2         3  2012-07-04        58811  1473    delivered    credit_card
# 3         4  2012-07-04        59453  2360    delivered    credit_card
# 4         6  2012-07-06        57821  2886    delivered         paypal
# 5         7  2012-07-06        57820  2886    delivered    credit_card
# 6         8  2012-07-06        57818  2886    delivered    credit_card
# 7         9  2012-07-06        49102  5262    delivered      apple_pay
# 8        10  2012-07-06        49101  5262    delivered         paypal
# 9        13  2012-07-06        40638  7456    delivered    credit_card
#
#   device_type    order_source
# 0     desktop     paid_search
# 1      mobile     paid_search
# 2     desktop          direct
# 3     desktop        referral
# 4      mobile  email_campaign
# 5      tablet  organic_search
# 6      mobile  email_campaign
# 7      tablet     paid_search
# 8     desktop  organic_search
# 9      tablet    social_media

# %%
df_orders_groupid = df_orders.groupby(['customer_id']).size().reset_index(name='count')
df_orders_groupid
# Out:
#        customer_id  count
# 0                1      6
# 1                2      4
# 2                3      3
# 3                4      1
# 4                5      5
# ...            ...    ...
# 90241       157554      1
# 90242       157555      2
# 90243       157557      1
# 90244       157561     22
# 90245       157563     22
#
# [90246 rows x 2 columns]

# %%
df_orders_groupid = df_orders_groupid[df_orders_groupid['count'] != 1]
df_orders_groupid
# Out:
#        customer_id  count
# 0                1      6
# 1                2      4
# 2                3      3
# 4                5      5
# 5                6     10
# ...            ...    ...
# 90234       157530      2
# 90238       157543      3
# 90242       157555      2
# 90244       157561     22
# 90245       157563     22
#
# [67888 rows x 2 columns]

# %%
df_orders_new = df_orders[df_orders['customer_id'].isin(df_orders_groupid['customer_id'])]
df_orders_new.sort_values(['customer_id', 'order_date'], ascending = True, inplace=True)
df_orders_new
# Out:
#         order_id  order_date  customer_id    zip order_status payment_method  \
# 4023        5280  2012-07-25            1  15201    delivered            cod
# 143252    184922  2014-05-31            1  15201     returned    credit_card
# 238890    308113  2015-07-31            1  15201    delivered            cod
# 374571    483190  2017-04-23            1  15201    delivered            cod
# 544446    702081  2020-02-24            1  15201    delivered    credit_card
# ...          ...         ...          ...    ...          ...            ...
# 549990    709267  2020-04-11       157563  59937    delivered    credit_card
# 557438    718824  2020-05-29       157563  59937    delivered    credit_card
# 559725    721751  2020-06-22       157563  59937    delivered         paypal
# 591841    763157  2021-05-27       157563  59937    delivered    credit_card
# 637881    822601  2022-08-31       157563  59937    cancelled            cod
#
#        device_type    order_source
# 4023       desktop     paid_search
# 143252      mobile        referral
# 238890      mobile     paid_search
# 374571      mobile     paid_search
# 544446      mobile  organic_search
# ...            ...             ...
# 549990      mobile  email_campaign
# 557438      mobile    social_media
# 559725      tablet  organic_search
# 591841      mobile    social_media
# 637881     desktop    social_media
#
# [624587 rows x 8 columns]

# %%
print(df_orders_new['customer_id'].unique())
df_orders_new['order_date'] = pd.to_datetime(df_orders_new['order_date'])
df_orders_new
# Out:
# [     1      2      3 ... 157555 157561 157563]
#         order_id order_date  customer_id    zip order_status payment_method  \
# 4023        5280 2012-07-25            1  15201    delivered            cod
# 143252    184922 2014-05-31            1  15201     returned    credit_card
# 238890    308113 2015-07-31            1  15201    delivered            cod
# 374571    483190 2017-04-23            1  15201    delivered            cod
# 544446    702081 2020-02-24            1  15201    delivered    credit_card
# ...          ...        ...          ...    ...          ...            ...
# 549990    709267 2020-04-11       157563  59937    delivered    credit_card
# 557438    718824 2020-05-29       157563  59937    delivered    credit_card
# 559725    721751 2020-06-22       157563  59937    delivered         paypal
# 591841    763157 2021-05-27       157563  59937    delivered    credit_card
# 637881    822601 2022-08-31       157563  59937    cancelled            cod
#
#        device_type    order_source
# 4023       desktop     paid_search
# 143252      mobile        referral
# 238890      mobile     paid_search
# 374571      mobile     paid_search
# 544446      mobile  organic_search
# ...            ...             ...
# 549990      mobile  email_campaign
# 557438      mobile    social_media
# 559725      tablet  organic_search
# 591841      mobile    social_media
# 637881     desktop    social_media
#
# [624587 rows x 8 columns]

# %%
print(f"Any NA/NaN values: {df_orders_new.isna().any().any()}")

print(f"Any Inf values: {np.isinf(df_orders_new.select_dtypes(include=[np.number])).any().any()}")
# Out:
# Any NA/NaN values: False
# Any Inf values: False

# %%
df_orders_new[df_orders_new['customer_id'] == 1]
# Out:
#         order_id order_date  customer_id    zip order_status payment_method  \
# 4023        5280 2012-07-25            1  15201    delivered            cod
# 143252    184922 2014-05-31            1  15201     returned    credit_card
# 238890    308113 2015-07-31            1  15201    delivered            cod
# 374571    483190 2017-04-23            1  15201    delivered            cod
# 544446    702081 2020-02-24            1  15201    delivered    credit_card
# 586950    756884 2021-04-24            1  15201         paid    credit_card
#
#        device_type    order_source
# 4023       desktop     paid_search
# 143252      mobile        referral
# 238890      mobile     paid_search
# 374571      mobile     paid_search
# 544446      mobile  organic_search
# 586950     desktop    social_media

# %%
gaps = df_orders_new[df_orders_new['customer_id'] == 1]['order_date'].diff().dt.days.astype(float)
print(gaps.tolist()[1:])
# Out:
# [675.0, 426.0, 632.0, 1037.0, 425.0]

# %%
gaps = []
for i in df_orders_new['customer_id'].unique():
    cur_gap = df_orders_new[df_orders_new['customer_id'] == i]['order_date'].diff().dt.days.astype(float)
    cur_gap = cur_gap.tolist()[1:]
    gaps.extend(cur_gap)

# %%
print(np.median(gaps))
# Out:
# 144.0

# %% [markdown]
# Đáp án cuối cùng có vẻ là 180 (closest to 144), mn check lại code xem

# %% [markdown]
# Q2. Phân khúc sản phẩm (segment) nào trong products.csv có tỷ suất lợi nhuận gộp trung bình cao nhất, với công thức (price − cogs)/price?

# %%
PRODUCTS = DATA_DIR + 'products.csv'
df_products = pd.read_csv(PRODUCTS)
df_products.head(10)
# Out:
#    product_id      product_name    category   segment size   color  \
# 0         536  SaigonFlex UC-01  Streetwear  Everyday    S   green
# 1         537  SaigonFlex UC-02  Streetwear  Everyday    M  silver
# 2         538  SaigonFlex UC-03  Streetwear  Everyday    L    pink
# 3         539  SaigonFlex UC-04  Streetwear  Everyday   XL  yellow
# 4         540  SaigonFlex UC-05  Streetwear  Everyday    S     red
# 5         541  SaigonFlex UC-06  Streetwear  Everyday    M   black
# 6         542  SaigonFlex UC-07  Streetwear  Everyday    L  orange
# 7         543  SaigonFlex UC-08  Streetwear  Everyday   XL    blue
# 8         544  SaigonFlex UC-09  Streetwear  Everyday    S   white
# 9         545  SaigonFlex UC-10  Streetwear  Everyday    M  purple
#
#           price          cogs
# 0  11059.650000   9704.842875
# 1   9523.076013   5393.870254
# 2  15951.633158  11371.919278
# 3  15753.717299   8573.172954
# 4  15766.334536  14063.570406
# 5  16095.853846  15291.061154
# 6   9213.817742   6152.066106
# 7     40.394178     22.487748
# 8  11334.106452   8528.915105
# 9  10045.678411   9091.338962

# %%
print(f"Any NA/NaN values: {df_products.isna().any().any()}")

print(f"Any Inf values: {np.isinf(df_products.select_dtypes(include=[np.number])).any().any()}")
# Out:
# Any NA/NaN values: False
# Any Inf values: False

# %%
df_products_groupid = df_products.groupby(['segment']).size().reset_index(name='count')
df_products_groupid
# Out:
#        segment  count
# 0   Activewear    598
# 1  All-weather    169
# 2     Balanced    306
# 3     Everyday    405
# 4  Performance    347
# 5      Premium    177
# 6     Standard    262
# 7       Trendy    148

# %%
result = df_products.groupby('segment')[['price', 'cogs']].sum()
result
# Out:
#                     price          cogs
# segment
# Activewear   1.553661e+06  1.216784e+06
# All-weather  6.531421e+05  5.084402e+05
# Balanced     2.824454e+06  2.212628e+06
# Everyday     3.057421e+06  2.433037e+06
# Performance  2.280777e+06  1.768000e+06
# Premium      4.226185e+05  3.413006e+05
# Standard     7.672912e+05  5.919552e+05
# Trendy       3.274922e+05  2.583084e+05

# %%
df_products['margin_pct'] = (df_products['price'] - df_products['cogs']) / df_products['price']

margin_sum = df_products.groupby('segment')['margin_pct'].sum()
result['avg_margin_pct'] = margin_sum / df_products_groupid.set_index('segment')['count']

print(result)
# Out:
#                     price          cogs  avg_margin_pct
# segment
# Activewear   1.553661e+06  1.216784e+06        0.265600
# All-weather  6.531421e+05  5.084402e+05        0.284176
# Balanced     2.824454e+06  2.212628e+06        0.258038
# Everyday     3.057421e+06  2.433037e+06        0.236343
# Performance  2.280777e+06  1.768000e+06        0.263650
# Premium      4.226185e+05  3.413006e+05        0.285377
# Standard     7.672912e+05  5.919552e+05        0.313442
# Trendy       3.274922e+05  2.583084e+05        0.240758

# %% [markdown]
# Phân khúc có avg_margin_pct cao nhất là Standard với 0.31

# %% [markdown]
# Q3. Trong các bản ghi trả hàng liên kết với sản phẩm thuộc danh mục Streetwear (join returns với products theo product_id), lý do trả hàng nào xuất hiện nhiều nhất?

# %%
RETURNS = DATA_DIR +'returns.csv'
df_returns = pd.read_csv(RETURNS)
df_returns.head(10)
# Out:
#     return_id  order_id  product_id return_date  return_reason  \
# 0  RET-000001         2         609  2012-07-25  late_delivery
# 1  RET-000002        32        1862  2012-07-16     wrong_size
# 2  RET-000003        35        2359  2012-07-16     wrong_size
# 3  RET-000004        47        1449  2012-07-11     wrong_size
# 4  RET-000005        47        1450  2012-07-25     wrong_size
# 5  RET-000006        59         671  2012-07-19      defective
# 6  RET-000007        67         604  2012-07-16     wrong_size
# 7  RET-000008       102         467  2012-07-17      defective
# 8  RET-000010       108         635  2012-07-30     wrong_size
# 9  RET-000012       132         103  2012-07-29   changed_mind
#
#    return_quantity  refund_amount
# 0                6       52458.01
# 1                2        5141.37
# 2                1        5315.95
# 3                4        6493.75
# 4                1        1740.76
# 5                1       10086.33
# 6                1        5713.22
# 7                1        9724.09
# 8                5       43387.54
# 9                2       19200.35

# %%
returns_products_merge = pd.merge(df_returns, df_products, on='product_id')
returns_products_merge.head(10)
# Out:
#         return_id  order_id  product_id return_date  return_reason  \
# 0      RET-000001         2         609  2012-07-25  late_delivery
# 1      RET-000002        32        1862  2012-07-16     wrong_size
# 2      RET-000003        35        2359  2012-07-16     wrong_size
# 3      RET-000004        47        1449  2012-07-11     wrong_size
# 4      RET-000005        47        1450  2012-07-25     wrong_size
# ...           ...       ...         ...         ...            ...
# 39934  RET-051470    832867         653  2022-12-27     wrong_size
# 39935  RET-051471    832890         792  2022-12-30  late_delivery
# 39936  RET-051481    833005         449  2022-12-31      defective
# 39937  RET-051494    833234        1085  2022-12-28     wrong_size
# 39938  RET-051504    833351        2254  2022-12-30  late_delivery
#
#        return_quantity  refund_amount       product_name    category  \
# 0                    6       52458.01   SaigonFlex UC-74  Streetwear
# 1                    2        5141.37   SaigonCore YY-57        GenZ
# 2                    1        5315.95   VietMotion UC-07  Streetwear
# 3                    4        6493.75     VietMode RP-41     Outdoor
# 4                    1        1740.76     VietMode RP-42     Outdoor
# ...                ...            ...                ...         ...
# 39934                3       24741.62   SaigonFlex UC-18  Streetwear
# 39935                1         560.50  HanoiStreet RP-80     Outdoor
# 39936                1       10002.55   SaigonFlex UM-54  Streetwear
# 39937                1         815.57    MekongFit RP-31     Outdoor
# 39938                3        1643.47   VietMotion RP-51     Outdoor
#
#           segment size   color         price          cogs  margin_pct
# 0        Everyday    M  yellow  10426.571034   8987.704231      0.1380
# 1          Trendy    L  orange   2656.232069   1842.628186      0.3063
# 2        Everyday   XL  yellow   5399.825901   3136.758866      0.4191
# 3      Activewear    M  yellow   1802.115000   1575.769356      0.1256
# 4      Activewear    L     red   1802.115000   1309.056336      0.2736
# ...           ...  ...     ...           ...           ...         ...
# 39934    Everyday    M    blue  10584.532362  10055.305744      0.0500
# 39935  Activewear    S  orange    811.886514    649.265645      0.2003
# 39936    Balanced    M  yellow  12600.871631  11279.040197      0.1049
# 39937  Activewear    M  purple   1139.500596    895.875369      0.2138
# 39938  Activewear    L   white    715.600872    486.680153      0.3199
#
# [39939 rows x 15 columns]

# %%
filtered_streetware = returns_products_merge[returns_products_merge['category'] == 'Streetwear']
filtered_streetware = filtered_streetware.groupby(['return_reason']).size().reset_index(name='count')
filtered_streetware
# Out:
#       return_reason  count
# 0      changed_mind   3830
# 1         defective   4330
# 2     late_delivery   2159
# 3  not_as_described   3854
# 4        wrong_size   7626

# %% [markdown]
# Lý do trả hàng xuất hiện nhiều nhất là wrong_size

# %% [markdown]
# Q4. Trong web_traffic.csv, nguồn truy cập (traffic_source) nào có tỷ lệ thoát trung bình (bounce_rate) thấp nhất trên tất cả các ngày xuất hiện nguồn đó trong cột traffic_source?

# %%
TRAFFIC = DATA_DIR + 'web_traffic.csv'
df_traffic = pd.read_csv(TRAFFIC)
df_traffic.head(10)
# Out:
#          date  sessions  unique_visitors  page_views  bounce_rate  \
# 0  2013-01-01      9760             7253       39093      0.00514
# 1  2013-01-02     10456             8151       47611      0.00406
# 2  2013-01-03     10076             7458       36963      0.00401
# 3  2013-01-04      9973             8063       53078      0.00562
# 4  2013-01-05     10223             7882       36790      0.00525
# 5  2013-01-06      9545             6992       47160      0.00438
# 6  2013-01-07     10203             7354       32749      0.00443
# 7  2013-01-08      9456             7459       31482      0.00440
# 8  2013-01-09      9162             7108       46717      0.00409
# 9  2013-01-10      9887             7878       38472      0.00544
#
#    avg_session_duration_sec  traffic_source
# 0                     102.9  organic_search
# 1                     120.5  organic_search
# 2                     263.6          direct
# 3                     151.8          direct
# 4                     168.6        referral
# 5                     263.6    social_media
# 6                     252.1  organic_search
# 7                     192.4     paid_search
# 8                     312.8  organic_search
# 9                     285.4  organic_search

# %%
print(f"Any NA/NaN values: {df_traffic.isna().any().any()}")

print(f"Any Inf values: {np.isinf(df_traffic.select_dtypes(include=[np.number])).any().any()}")
# Out:
# Any NA/NaN values: False
# Any Inf values: False

# %%
avg_bounce_rate = df_traffic.groupby('traffic_source')['bounce_rate'].mean()
avg_bounce_rate
# Out:
# traffic_source
# direct            0.004511
# email_campaign    0.004458
# organic_search    0.004504
# paid_search       0.004478
# referral          0.004499
# social_media      0.004476
# Name: bounce_rate, dtype: float64

# %% [markdown]
# Tỉ lệ bounce_rate thấp nhất là từ email_campaing. Mn thử đọc lại đề xem t hiểu đúng ko

# %% [markdown]
# Q5. Tỷ lệ phần trăm các dòng trong order_items.csv có áp dụng khuyến mãi (tức là promo_id không null) xấp xỉ là bao nhiêu?

# %%
ITEMS = DATA_DIR + 'order_items.csv'
df_items = pd.read_csv(ITEMS)
df_items.head(10)
# Out:
#    order_id  product_id  quantity  unit_price  discount_amount promo_id  \
# 0         1        2400         7     1138.22              0.0      NaN
# 1         2         609         7    10166.25              0.0      NaN
# 2         3         396         3    11220.33              0.0      NaN
# 3         4         635         5    10639.25              0.0      NaN
# 4         6        1935         1     1597.84              0.0      NaN
# 5         7        1934         6     1633.49              0.0      NaN
# 6         8        1934         6     1602.92              0.0      NaN
# 7         8        1935         4     1642.51              0.0      NaN
# 8         9        1432         8     4049.64              0.0      NaN
# 9        10        1431         5     3977.37              0.0      NaN
#
#   promo_id_2
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN

# %%
non_null_count = df_items['promo_id'].count()

total_count = len(df_items)

percentage_non_null = (non_null_count / total_count) * 100

print(f"Non-null percentage: {percentage_non_null:.2f}%")
# Out:
# Non-null percentage: 38.66%

# %% [markdown]
# Q6. Trong customers.csv, xét các khách hàng có age_group khác null, nhóm tuổi nào có số đơn hàng trung bình trên mỗi khách hàng cao nhất? (tổng số đơn / số khách hàng trong nhóm)

# %%
CUSTOMERS = DATA_DIR + 'customers.csv'
df_customers = pd.read_csv(CUSTOMERS)
df_customers.head(10)
# Out:
#    customer_id    zip       city signup_date  gender age_group  \
# 0            1  15201  Hai Phong  2021-12-30  Female     35-44
# 1            2  15201  Hai Phong  2013-12-27  Female     45-54
# 2            3  15201  Hai Phong  2018-07-24  Female     18-24
# 3            4  15201  Hai Phong  2017-11-29    Male     35-44
# 4            5  15201  Hai Phong  2022-09-23    Male       55+
# 5            6  15202     Phu Ly  2022-04-14  Female     25-34
# 6            8  15202     Phu Ly  2015-09-11    Male     45-54
# 7            9  15202     Phu Ly  2020-02-14    Male     35-44
# 8           10  15202     Phu Ly  2014-03-03    Male     25-34
# 9           11  15203   Viet Tri  2017-11-07    Male     35-44
#
#   acquisition_channel
# 0        social_media
# 1      email_campaign
# 2      organic_search
# 3            referral
# 4      organic_search
# 5      organic_search
# 6        social_media
# 7      email_campaign
# 8      organic_search
# 9      organic_search

# %%
print(f"Any NA/NaN values: {df_customers.isna().any().any()}")

print(f"Any Inf values: {np.isinf(df_customers.select_dtypes(include=[np.number])).any().any()}")
# Out:
# Any NA/NaN values: False
# Any Inf values: False

# %%
customers_orders_merge = pd.merge(df_customers, df_orders, on='customer_id')
customers_orders_merge.head(10)
# Out:
#    customer_id  zip_x       city signup_date  gender age_group  \
# 0            1  15201  Hai Phong  2021-12-30  Female     35-44
# 1            1  15201  Hai Phong  2021-12-30  Female     35-44
# 2            1  15201  Hai Phong  2021-12-30  Female     35-44
# 3            1  15201  Hai Phong  2021-12-30  Female     35-44
# 4            1  15201  Hai Phong  2021-12-30  Female     35-44
# 5            1  15201  Hai Phong  2021-12-30  Female     35-44
# 6            2  15201  Hai Phong  2013-12-27  Female     45-54
# 7            2  15201  Hai Phong  2013-12-27  Female     45-54
# 8            2  15201  Hai Phong  2013-12-27  Female     45-54
# 9            2  15201  Hai Phong  2013-12-27  Female     45-54
#
#   acquisition_channel  order_id  order_date  zip_y order_status  \
# 0        social_media      5280  2012-07-25  15201    delivered
# 1        social_media    184922  2014-05-31  15201     returned
# 2        social_media    308113  2015-07-31  15201    delivered
# 3        social_media    483190  2017-04-23  15201    delivered
# 4        social_media    702081  2020-02-24  15201    delivered
# 5        social_media    756884  2021-04-24  15201         paid
# 6      email_campaign    117673  2013-09-20  15201    delivered
# 7      email_campaign    125576  2013-10-28  15201    cancelled
# 8      email_campaign    231562  2014-11-13  15201    cancelled
# 9      email_campaign    815219  2022-07-06  15201    delivered
#
#   payment_method device_type    order_source
# 0            cod     desktop     paid_search
# 1    credit_card      mobile        referral
# 2            cod      mobile     paid_search
# 3            cod      mobile     paid_search
# 4    credit_card      mobile  organic_search
# 5    credit_card     desktop    social_media
# 6         paypal      mobile    social_media
# 7    credit_card     desktop          direct
# 8  bank_transfer     desktop  organic_search
# 9      apple_pay      mobile     paid_search

# %%
temp = customers_orders_merge.groupby(['age_group']).size().reset_index(name='count_order')
temp
# Out:
#   age_group  count_order
# 0     18-24        89057
# 1     25-34       190622
# 2     35-44       170368
# 3     45-54       124138
# 4       55+        72760

# %%
total_per_age = df_customers.groupby(['age_group']).size().reset_index(name='count_num')
total_per_age
# Out:
#   age_group  count_num
# 0     18-24      17039
# 1     25-34      36342
# 2     35-44      31920
# 3     45-54      23172
# 4       55+      13457

# %%
merged2 = pd.merge(total_per_age, temp, on='age_group')
merged2['avg_orders_per_person'] = merged2['count_order'] / merged2['count_num']
merged2
# Out:
#   age_group  count_num  count_order  avg_orders_per_person
# 0     18-24      17039        89057               5.226656
# 1     25-34      36342       190622               5.245226
# 2     35-44      31920       170368               5.337343
# 3     45-54      23172       124138               5.357241
# 4       55+      13457        72760               5.406851

# %% [markdown]
# Có vẻ là 55+

# %% [markdown]
# Q7. Vùng (region) nào trong geography.csv tạo ra tổng doanh thu cao nhất trong sales_train.csv?

# %%
GEOGRAPHY = DATA_DIR + 'geography.csv'
SALES = DATA_DIR + 'sales.csv'
df_geography = pd.read_csv(GEOGRAPHY)
df_sales = pd.read_csv(SALES)
df_geography.head()
# Out:
#      zip       city region      district
# 0  15201  Hai Phong   East  District #13
# 1  15202     Phu Ly   East  District #13
# 2  15203   Viet Tri   East  District #13
# 3  15204  Bac Giang   East  District #13
# 4  15205  Bac Giang   East  District #13

# %%
df_sales.head()
# Out:
#          Date     Revenue        COGS
# 0  2012-07-04  5123547.94  3982991.19
# 1  2012-07-05  2751773.45  2150580.23
# 2  2012-07-06  3054029.42  2517632.84
# 3  2012-07-07  2667930.94  2108246.62
# 4  2012-07-08  2360851.90  1808622.79

# %% [markdown]
# Ko hiểu đề lắm, mn xem thử nhé

# %% [markdown]
# Q8. Trong các đơn hàng có order_status = ’cancelled’ trong orders.csv, phương thức thanh toán nào được sử dụng nhiều nhất?

# %%
cancelled = df_orders[df_orders['order_status'] == 'cancelled'].groupby('payment_method').size().reset_index(name='count')
cancelled
# Out:
#   payment_method  count
# 0      apple_pay   5190
# 1  bank_transfer   2535
# 2            cod  15468
# 3    credit_card  28452
# 4         paypal   7817

# %% [markdown]
# Trong những đơn cancelled thì ngta dùng method là credit_card nhiều nhất

# %% [markdown]
# Q9. Trong bốn kích thước sản phẩm (S, M, L, XL), kích thước nào có tỷ lệ trả hàng cao nhất, được định nghĩa là số bản ghi trong returns chia cho số dòng trong order_items (join với products theo product_id)?

# %%
items_products_merge = pd.merge(df_items, df_products, on='product_id').sort_values('product_id')
items_products_merge.head(10)
# Out:
#         order_id  product_id  quantity  unit_price  discount_amount  \
# 711768    830967           1         8     3912.79          6260.46
# 524751    605359           3         6    10860.12             0.00
# 617708    716531           3         3    10803.00             0.00
# 408188    467863           3         2    11046.37             0.00
# 611587    709129           3         3     9806.78          3530.44
# 459404    528720           3         1    11113.34             0.00
# 454582    522992           3         3    10758.99             0.00
# 522279    602347           3         8    10827.47             0.00
# 525397    606130           3         7     9079.96         11440.75
# 683213    795836           3         5     9572.69          5743.61
#
#           promo_id promo_id_2      product_name category      segment size  \
# 711768  PROMO-0050        NaN  DragonWear MA-01   Casual  All-weather    M
# 524751         NaN        NaN  DragonWear MA-03   Casual  All-weather   XL
# 617708         NaN        NaN  DragonWear MA-03   Casual  All-weather   XL
# 408188         NaN        NaN  DragonWear MA-03   Casual  All-weather   XL
# 611587  PROMO-0037        NaN  DragonWear MA-03   Casual  All-weather   XL
# 459404         NaN        NaN  DragonWear MA-03   Casual  All-weather   XL
# 454582         NaN        NaN  DragonWear MA-03   Casual  All-weather   XL
# 522279         NaN        NaN  DragonWear MA-03   Casual  All-weather   XL
# 525397  PROMO-0028        NaN  DragonWear MA-03   Casual  All-weather   XL
# 683213  PROMO-0047        NaN  DragonWear MA-03   Casual  All-weather   XL
#
#         color         price          cogs  margin_pct
# 711768  black   4945.500000   2732.883300      0.4474
# 524751   blue  10831.377188  10289.808329      0.0500
# 617708   blue  10831.377188  10289.808329      0.0500
# 408188   blue  10831.377188  10289.808329      0.0500
# 611587   blue  10831.377188  10289.808329      0.0500
# 459404   blue  10831.377188  10289.808329      0.0500
# 454582   blue  10831.377188  10289.808329      0.0500
# 522279   blue  10831.377188  10289.808329      0.0500
# 525397   blue  10831.377188  10289.808329      0.0500
# 683213   blue  10831.377188  10289.808329      0.0500

# %% [markdown]
# Đang ko hiểu lắm, mn check thử xem. Số bản ghi trong returns/số dòng của order_items là ntn

# %% [markdown]
# Q10. Trong payments.csv, kế hoạch trả góp nào có giá trị thanh toán trung bình trên mỗi đơn hàng cao nhất?

# %%
PAYMENTS = DATA_DIR + 'payments.csv'
df_payments = pd.read_csv(PAYMENTS)
df_payments.head(10)
# Out:
#    order_id payment_method  payment_value  installments
# 0         1    credit_card        7967.54             3
# 1         2            cod       71163.75             1
# 2         3    credit_card       33660.99             3
# 3         4    credit_card       53196.25             3
# 4         6         paypal        1597.84             1
# 5         7    credit_card        9800.94            12
# 6         8    credit_card       16187.56             6
# 7         9      apple_pay       32397.12            12
# 8        10         paypal       19886.85             1
# 9        13    credit_card       36037.68             3

# %%
total_install = df_payments.groupby(['installments'])['payment_value'].sum().reset_index(name='sum')
total_install
# Out:
#    installments           sum
# 0             1  6.338560e+09
# 1             2  7.750703e+05
# 2             3  5.342276e+09
# 3             6  2.686932e+09
# 4            12  1.312327e+09

# %%
num_install = df_payments.groupby(['installments']).size().reset_index(name='num')
num_install
# Out:
#    installments     num
# 0             1  262866
# 1             2    1094
# 2             3  218949
# 3             6  109910
# 4            12   54126

# %%
avg = pd.merge(total_install, num_install, on='installments')
avg['avg_payment_value'] = avg['sum'] / avg['num']
avg
# Out:
#    installments           sum     num  avg_payment_value
# 0             1  6.338560e+09  262866       24113.274166
# 1             2  7.750703e+05    1094         708.473729
# 2             3  5.342276e+09  218949       24399.635486
# 3             6  2.686932e+09  109910       24446.654403
# 4            12  1.312327e+09   54126       24245.772694

# %% [markdown]
# Cao nhất đang trông là 6 kỳ, mn check code nhé
